# %%
##python list means varabls that can hold multi values
#FUTUTRS ordered 
        #mutable 
x=["thomas",5,5. 5] 
print (x)
# Out:
# ['thomas', 5, 5.5]

# %%
food=["shiro", "pasta","egg",12]
print ()
# if you want to call only one item we use index number (0 is alwas the frist one then continue), (if you want you can use - then it wil
#start from the last one ) 
print(food[-1])
# Out:
# 12

# %%
#how to add another lists 

food=["shiro", "pasta","egg",12]
#food.append("shiro").  if you run it know it will add it at the end 
food.append("shiro")
print (food)
# Out:
# ['shiro', 'pasta', 'egg', 12, 'shiro']

# %%
##wht if i want to add it in the spesfic palce 
food=["shiro", "pasta","egg",12]
food.insert (0,"shiro")
print (food)
# Out:
# ['shiro', 'shiro', 'pasta', 'egg', 12]

# %%
food=["shiro", "pasta","egg",12]
food.insert(i)

# %%
#multiple items
food=["shiro", "pasta","egg",12]
food.extend(["doro", "bekolo"])
print (food)
# Out:
# ['shiro', 'pasta', 'egg', 12, 'doro', 'bekolo']

# %%
       ##remove
##remove by value
food=["shiro", "pasta","egg",12]
food.remove(12)
print (food)
# Out:
# ['shiro', 'pasta', 'egg']

# %%
#remove by index 
food=["shiro", "pasta","egg",12]
food. pop (0)
print (food)
# Out:
# ['pasta', 'egg', 12]

# %%
# remove the whole value 
food=["shiro", "pasta","egg",12]
food.clear ()
print (food)
# Out:
# []

# %%
##modify
food=["shiro", "pasta","egg",12]
food[1]="chechebsa"
print (food)
# Out:
# ['shiro', 'chechebsa', 'egg', 12]

# %%
#assignment to do 
tasks = []  # empty list to store tasks

while True:
    print("\n--- TO-DO LIST ---")
    print("1. Add a task")
    print("2. View tasks")
    print("3. Remove a task")
    print("4. Exit")

    choice = input("Choose an option (1–4): ")

    if choice == "1":
        task = input("Enter a new task: ")
        tasks.append(task)
        print("Task added!")

    elif choice == "2":
        print("\nYour tasks:")
        for i, t in enumerate(tasks, start=1):
            print(f"{i}. {t}")

    elif choice == "3":
        num = int(input("Enter task number to remove: "))
        if 1 <= num <= len(tasks):
            tasks.pop(num - 1)
            print("Task removed!")
        else:
            print("Invalid number!")

    elif choice == "4":
        print("Goodbye!")
        break

    else:
        print("Invalid choice! Try again.")
# Out:
# --- TO-DO LIST ---
# 1. Add a task
# 2. View tasks
# 3. Remove a task
# 4. Exit
# Choose an option (1–4):  1
# Enter a new task:  Dfghjk
# Task added!
#
# --- TO-DO LIST ---
# 1. Add a task
# 2. View tasks
# 3. Remove a task
# 4. Exit

# %%
todo= []
def add():
    new = input ("add  new to do:")
    todo.append (new )

def rem ():
    rm = input(" what do u want to removce ?")
    todo.remove (rm)

def main():
    print ("wellcome")
    print ("ur to do")
    print ("todo")
    print ("press 1 to add new")
    print ("press 2 to remove")
    print ("press 3 to remove")
    c= in(input())
    if c==1:
        add()
    elif c==2:
        rem()
    else:
        main ()

# %%
x =input ("what is your name")
y= int(input ("wllcome" f" {x} I am very gald to see you. which gread are you ?"))
z= input ("how is gooing class?")
print ("I am here to help you, press one to contunie if you are willing")

# %%
#phython function- reuse of the code many times 
def x():
    print ("happy birthday to u")
    print ("happy birthday to u")
    print ("happy birthday to u")

x()
x()
# Out:
# happy birthday to u
# happy birthday to u
# happy birthday to u
# happy birthday to u
# happy birthday to u
# happy birthday to u

# %%
#while loop : repeation of codes again and again as long as the condtion is true 
x= input ("inter ur name:")
if x=="":
    print yo
